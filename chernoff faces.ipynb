# %%
library(aplpack)

mkt_industry<- c("large cap", "mid cap", "small cap","energe","material", "industry","consumer", "essential consumer","medical","finance","IT","mobile","utility")
mkt_cap <- c(81.36,9.66,8.98,4.02,7.46,10.60,14.51,7.60,5.44,11.88,33.40,2.43,2.67)
rate_April<- c(-0.04,-0.64,-0.65,-1.61,-1.15,-0.97,-1.72,0.46,-0.32,-0.90,1.31,1.0,0.67)
vol_April<-c(0.55,0.72,0.74,1.11,0.91,0.67,0.87,1.03,0.80,0.89,0.99,1.07,0.88)
foreigner<-c(40.11,17.45,11.90,37.60,30.93,19.25,32.03,29.88,13.94,39.83,45.75,44.31,28.80)
volume<- c(31.96,18.13,49.91,1.77,5.78,17.29,15.45,7.56,11.68,16.86,20.46,1.71,1.14)
per<-c(12.81,18.80,18.10,10.95,12.05,29.63,10.06,18.79,35.66,9.47,15.60,11.87,5.44)
pbr<-c(1.09,1.27,1.19,1.03,0.79,1.02,0.83,2.20,3.33,0.69,1.71,1.05,0.44)
roe<-c(8.83,7.03,6.82,9.81,6.77,3.58,8.56,12.28,10.33,7.52,11.38,9.10,8.29)
eps<-c(353.90,266.79,129.93,707.33,520.94,167.23,748.05,588.70,243.57,308.70,428.34,64.88,386.15)
profit_rate<- c(8.7,5.53,6.16,7.43,7.85,4.23,5.47,9.04,9.65,11.76,12.56,7.17,15.41)
com<-c(-288342,-20462,-16784,-7865,-10822,-89375,-40949,-16449,-6368,-39055,-148887,11692,-7511)
num<-c(99,99,303,12,56,71,106,51,76,39,81,3,6)
asset<-c(86.12,7.43,6.46,3.19,4.49,10.17,9.82,1.83,0.62,56.73,8.51,1.32,3.32)
debt_rate<-c(326.75,318.54,266.38,187.92,83.96,297.16,118.93,112.68,66.46,1129.54,45.85,126.73,162.71)
ytd_17<-c(10.61,8.23,1.86,10.70,0,5.57,1.48,0.55,-0.33,9.83,20.18,11.26,2.40)

test <- data.frame(mkt_industry,mkt_cap,ytd_17,rate_April,vol_April,foreigner,volume,per,pbr,roe,eps,profit_rate,com,num,asset,debt_rate)

test
# Out:
#    mkt_industry       mkt_cap ytd_17 rate_April vol_April foreigner volume
# 1  large cap          81.36   10.61  -0.04      0.55      40.11     31.96
# 2  mid cap             9.66    8.23  -0.64      0.72      17.45     18.13
# 3  small cap           8.98    1.86  -0.65      0.74      11.90     49.91
# 4  energe              4.02   10.70  -1.61      1.11      37.60      1.77
# 5  material            7.46    0.00  -1.15      0.91      30.93      5.78
# 6  industry           10.60    5.57  -0.97      0.67      19.25     17.29
# 7  consumer           14.51    1.48  -1.72      0.87      32.03     15.45
# 8  essential consumer  7.60    0.55   0.46      1.03      29.88      7.56
# 9  medical             5.44   -0.33  -0.32      0.80      13.94     11.68
# 10 finance            11.88    9.83  -0.90      0.89      39.83     16.86
# 11 IT                 33.40   20.18   1.31      0.99      45.75     20.46
# 12 mobile              2.43   11.26   1.00      1.07      44.31      1.71
# 13 utility             2.67    2.40   0.67      0.88      28.80      1.14
#    per   pbr  roe   eps    profit_rate com     num asset debt_rate
# 1  12.81 1.09  8.83 353.90  8.70       -288342  99 86.12  326.75
# 2  18.80 1.27  7.03 266.79  5.53        -20462  99  7.43  318.54
# 3  18.10 1.19  6.82 129.93  6.16        -16784 303  6.46  266.38
# 4  10.95 1.03  9.81 707.33  7.43         -7865  12  3.19  187.92
# 5  12.05 0.79  6.77 520.94  7.85        -10822  56  4.49   83.96
# 6  29.63 1.02  3.58 167.23  4.23        -89375  71 10.17  297.16
# 7  10.06 0.83  8.56 748.05  5.47        -40949 106  9.82  118.93
# 8  18.79 2.20 12.28 588.70  9.04        -16449  51  1.83  112.68
# 9  35.66 3.33 10.33 243.57  9.65         -6368  76  0.62   66.46
# 10  9.47 0.69  7.52 308.70 11.76        -39055  39 56.73 1129.54
# 11 15.60 1.71 11.38 428.34 12.56       -148887  81  8.51   45.85
# 12 11.87 1.05  9.10  64.88  7.17         11692   3  1.32  126.73
# 13  5.44 0.44  8.29 386.15 15.41         -7511   6  3.32  162.71

# %%
# 1변수 분석
summary(test)
# Out:
#              mkt_industry    mkt_cap          ytd_17         rate_April
#  consumer          :1     Min.   : 2.43   Min.   :-0.330   Min.   :-1.7200
#  energe            :1     1st Qu.: 5.44   1st Qu.: 1.480   1st Qu.:-0.9700
#  essential consumer:1     Median : 8.98   Median : 5.570   Median :-0.6400
#  finance           :1     Mean   :15.39   Mean   : 6.334   Mean   :-0.3508
#  industry          :1     3rd Qu.:11.88   3rd Qu.:10.610   3rd Qu.: 0.4600
#  IT                :1     Max.   :81.36   Max.   :20.180   Max.   : 1.3100
#  (Other)           :7
#    vol_April        foreigner         volume           per
#  Min.   :0.5500   Min.   :11.90   Min.   : 1.14   Min.   : 5.44
#  1st Qu.:0.7400   1st Qu.:19.25   1st Qu.: 5.78   1st Qu.:10.95
#  Median :0.8800   Median :30.93   Median :15.45   Median :12.81
#  Mean   :0.8638   Mean   :30.14   Mean   :15.36   Mean   :16.09
#  3rd Qu.:0.9900   3rd Qu.:39.83   3rd Qu.:18.13   3rd Qu.:18.79
#  Max.   :1.1100   Max.   :45.75   Max.   :49.91   Max.   :35.66
#
#       pbr            roe              eps          profit_rate
#  Min.   :0.44   Min.   : 3.580   Min.   : 64.88   Min.   : 4.230
#  1st Qu.:0.83   1st Qu.: 7.030   1st Qu.:243.57   1st Qu.: 6.160
#  Median :1.05   Median : 8.560   Median :353.90   Median : 7.850
#  Mean   :1.28   Mean   : 8.485   Mean   :378.04   Mean   : 8.535
#  3rd Qu.:1.27   3rd Qu.: 9.810   3rd Qu.:520.94   3rd Qu.: 9.650
#  Max.   :3.33   Max.   :12.280   Max.   :748.05   Max.   :15.410
#
#       com               num             asset         debt_rate
#  Min.   :-288342   Min.   :  3.00   Min.   : 0.62   Min.   :  45.85
#  1st Qu.: -40949   1st Qu.: 39.00   1st Qu.: 3.19   1st Qu.: 112.68
#  Median : -16784   Median : 71.00   Median : 6.46   Median : 162.71
#  Mean   : -52398   Mean   : 77.08   Mean   :15.39   Mean   : 249.51
#  3rd Qu.:  -7865   3rd Qu.: 99.00   3rd Qu.: 9.82   3rd Qu.: 297.16
#  Max.   :  11692   Max.   :303.00   Max.   :86.12   Max.   :1129.54

# %%
# 히스토그램
# library(ggplot2)
ggplot(test, aes(x=ytd_17)) + geom_histogram() + xlab("수익률(연초대비)")
# ggplot(test, aes(x=ytd_17)) + geom_density()
ggplot(test, aes(x=foreigner)) + geom_histogram() + xlab("외국인비중")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# 산점도
ggplot(test, aes(x=ytd_17, y=foreigner)) + geom_point() + xlab("수익률(연초대비)") + ylab("외국인비중")
ggplot(test, aes(x=per, y=pbr)) + geom_point() + xlab("PER") + ylab("PBR")
# Out:
# plot without title
# plot without title

# %%
# pairs(test[,2:16])
pairs(test[,c('mkt_cap', 'ytd_17', 'rate_April', 'vol_April', 'foreigner', 'volume')])
# Out:
# plot without title

# %%
library(corrplot)
mcor <- cor(test[,2:16])
round(mcor, digits=2)
corrplot(mcor)
# Out:
#             mkt_cap ytd_17 rate_April vol_April foreigner volume per   pbr
# mkt_cap      1.00    0.41   0.18      -0.54      0.36      0.46  -0.10 -0.04
# ytd_17       0.41    1.00   0.39       0.17      0.67      0.06  -0.24 -0.16
# rate_April   0.18    0.39   1.00       0.19      0.33     -0.09  -0.04  0.24
# vol_April   -0.54    0.17   0.19       1.00      0.49     -0.65  -0.35  0.02
# foreigner    0.36    0.67   0.33       0.49      1.00     -0.34  -0.64 -0.33
# volume       0.46    0.06  -0.09      -0.65     -0.34      1.00   0.19  0.02
# per         -0.10   -0.24  -0.04      -0.35     -0.64      0.19   1.00  0.77
# pbr         -0.04   -0.16   0.24       0.02     -0.33      0.02   0.77  1.00
# roe          0.11    0.20   0.48       0.56      0.41     -0.26  -0.11  0.53
# eps          0.02   -0.11  -0.37       0.40      0.31     -0.35  -0.39 -0.10
# profit_rate  0.07    0.20   0.56       0.26      0.37     -0.26  -0.35  0.02
# com         -0.97   -0.47  -0.19       0.55     -0.34     -0.45   0.02  0.05
# num          0.16   -0.21  -0.19      -0.49     -0.55      0.92   0.24  0.09
# asset        0.81    0.31  -0.05      -0.52      0.36      0.39  -0.23 -0.24
# debt_rate    0.07    0.18  -0.25      -0.20      0.13      0.21  -0.21 -0.34
#             roe   eps   profit_rate com   num   asset debt_rate
# mkt_cap      0.11  0.02  0.07       -0.97  0.16  0.81  0.07
# ytd_17       0.20 -0.11  0.20       -0.47 -0.21  0.31  0.18
# rate_April   0.48 -0.37  0.56       -0.19 -0.19 -0.05 -0.25
# vol_April    0.56  0.40  0.26        0.55 -0.49 -0.52 -0.20
# foreigner    0.41  0.31  0.37       -0.34 -0.55  0.36  0.13
# volume      -0.26 -0.35 -0.26       -0.45  0.92  0.39  0.21
# per         -0.11 -0.39 -0.35        0.02  0.24 -0.23 -0.21
# pbr          0.53 -0.10  0.02        0.05  0.09 -0.24 -0.34
# roe          1.00  0.41  0.46       -0.03 -0.24 -0.09 -0.33
# eps          0.41  1.00  0.08        0.01 -0.26 -0.07 -0.21
# profit_rate  0.46  0.08  1.00       -0.07 -0.37  0.14  0.14
# com         -0.03  0.01 -0.07        1.00 -0.12 -0.76 -0.08
# num         -0.24 -0.26 -0.37       -0.12  1.00  0.04 -0.02
# asset       -0.09 -0.07  0.14       -0.76  0.04  1.00  0.61
# debt_rate   -0.33 -0.21  0.14       -0.08 -0.02  0.61  1.00
# Plot with title ""

# %%
# face.type = 1 : the elements of the faces are painted
test2 <- test
test2$per <- test2$per * -1
test2
faces(test2[,-1], face.type = 1, main = "chernoff faces : face.type =1")
# Out:
#    mkt_industry       mkt_cap ytd_17 rate_April vol_April foreigner volume
# 1  large cap          81.36   10.61  -0.04      0.55      40.11     31.96
# 2  mid cap             9.66    8.23  -0.64      0.72      17.45     18.13
# 3  small cap           8.98    1.86  -0.65      0.74      11.90     49.91
# 4  energe              4.02   10.70  -1.61      1.11      37.60      1.77
# 5  material            7.46    0.00  -1.15      0.91      30.93      5.78
# 6  industry           10.60    5.57  -0.97      0.67      19.25     17.29
# 7  consumer           14.51    1.48  -1.72      0.87      32.03     15.45
# 8  essential consumer  7.60    0.55   0.46      1.03      29.88      7.56
# 9  medical             5.44   -0.33  -0.32      0.80      13.94     11.68
# 10 finance            11.88    9.83  -0.90      0.89      39.83     16.86
# 11 IT                 33.40   20.18   1.31      0.99      45.75     20.46
# 12 mobile              2.43   11.26   1.00      1.07      44.31      1.71
# 13 utility             2.67    2.40   0.67      0.88      28.80      1.14
#    per    pbr  roe   eps    profit_rate com     num asset debt_rate
# 1  -12.81 1.09  8.83 353.90  8.70       -288342  99 86.12  326.75
# 2  -18.80 1.27  7.03 266.79  5.53        -20462  99  7.43  318.54
# 3  -18.10 1.19  6.82 129.93  6.16        -16784 303  6.46  266.38
# 4  -10.95 1.03  9.81 707.33  7.43         -7865  12  3.19  187.92
# 5  -12.05 0.79  6.77 520.94  7.85        -10822  56  4.49   83.96
# 6  -29.63 1.02  3.58 167.23  4.23        -89375  71 10.17  297.16
# 7  -10.06 0.83  8.56 748.05  5.47        -40949 106  9.82  118.93
# 8  -18.79 2.20 12.28 588.70  9.04        -16449  51  1.83  112.68
# 9  -35.66 3.33 10.33 243.57  9.65         -6368  76  0.62   66.46
# 10  -9.47 0.69  7.52 308.70 11.76        -39055  39 56.73 1129.54
# 11 -15.60 1.71 11.38 428.34 12.56       -148887  81  8.51   45.85
# 12 -11.87 1.05  9.10  64.88  7.17         11692   3  1.32  126.73
# 13  -5.44 0.44  8.29 386.15 15.41         -7511   6  3.32  162.71
# effect of variables:
#  modified item       Var
#  "height of face   " "mkt_cap"
#  "width of face    " "ytd_17"
#  "structure of face" "rate_April"
#  "height of mouth  " "vol_April"
#  "width of mouth   " "foreigner"
#  "smiling          " "volume"
#  "height of eyes   " "per"
#  "width of eyes    " "pbr"
#  "height of hair   " "roe"
#  "width of hair   "  "eps"
#  "style of hair   "  "profit_rate"
#  "height of nose  "  "com"
#  "width of nose   "  "num"
#  "width of ear    "  "asset"
#  "height of ear   "  "debt_rate"
# Plot with title "chernoff faces : face.type =1"

# %%
# putting labels as face names : labels
faces(test2[,-1], face.type = 1, labels =  c("대형주", "중형주", "소형주","에너지","소재", "산업재","경기소비재", "필수소비재","의료","금융","IT","통신서비스","유틸리티"),
      main = "putting labels as face names : labels = ")
# Out:
# effect of variables:
#  modified item       Var
#  "height of face   " "mkt_cap"
#  "width of face    " "ytd_17"
#  "structure of face" "rate_April"
#  "height of mouth  " "vol_April"
#  "width of mouth   " "foreigner"
#  "smiling          " "volume"
#  "height of eyes   " "per"
#  "width of eyes    " "pbr"
#  "height of hair   " "roe"
#  "width of hair   "  "eps"
#  "style of hair   "  "profit_rate"
#  "height of nose  "  "com"
#  "width of nose   "  "num"
#  "width of ear    "  "asset"
#  "height of ear   "  "debt_rate"
# Plot with title "putting labels as face names : labels = "

# %%
# Overlapping Chernoff faces over scatter plot  #

plot(test[,c("ytd_17", "foreigner")],  bty="n", # To make a plot with no box around the plot area 
     main = "Chernoff faces of test")

test_1_faces <- faces(test[,-1], scale = TRUE, plot=FALSE)


plot.faces(test_1_faces,  test[,c("ytd_17")],  test[,c("foreigner")],  width = 3,  height = 7,labels =  c("대형주", "중형주", "소형주","에너지","소재", "산업재","경기소비재", "필수소비재","의료","금융","IT","통신서비스","유틸리티"),
           main = "putting labels as face names : labels = ")
# Out:
# effect of variables:
#  modified item       Var
#  "height of face   " "mkt_cap"
#  "width of face    " "ytd_17"
#  "structure of face" "rate_April"
#  "height of mouth  " "vol_April"
#  "width of mouth   " "foreigner"
#  "smiling          " "volume"
#  "height of eyes   " "per"
#  "width of eyes    " "pbr"
#  "height of hair   " "roe"
#  "width of hair   "  "eps"
#  "style of hair   "  "profit_rate"
#  "height of nose  "  "com"
#  "width of nose   "  "num"
#  "width of ear    "  "asset"
#  "height of ear   "  "debt_rate"
# Plot with title "Chernoff faces of test"
